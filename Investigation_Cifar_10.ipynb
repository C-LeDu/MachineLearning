# %% [markdown]
# # CIFAR-10 investigation 4aIBD

# %%
from IPython.display import Image

# %% [markdown]
# ## 1_CIFAR10_LINEAR_S10_LR_0.5

# %%
# %load CIFAR10_LINEAR_S10_LR_0.5.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
#from keras.callbacks import *
import numpy as np
import keras


experiment_name="_LINEAR_S10_LR_0.5"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32*32*3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32*32*3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

#tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

linear_model = Sequential()
linear_model.add(Dense(10,
                       activation=sigmoid,
                       input_dim=(32*32*3)))



linear_model.compile(sgd(lr=0.5),
                     mse, metrics=[categorical_accuracy])


linear_model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=5000,
                 verbose=1,
                 #callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|-----------|--------|----------------------|-------------------|
# |    45 |        41  |   5000 |     vers 2322 epochs |               40% |

# %% [markdown]
# ## 2_CIFAR10_LINEAR_S10_LR_0.05

# %%
# %load CIFAR10_LINEAR_S10_LR_0.05.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


experiment_name="_LINEAR_S10_LR_0.05"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32*32*3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32*32*3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

linear_model = Sequential()
linear_model.add(Dense(10,
                       activation=sigmoid,
                       input_dim=(32*32*3)))



linear_model.compile(sgd(lr=0.05,),
                     mse, metrics=[categorical_accuracy])


linear_model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=5000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |    41 |         40 |   5000 |                  non |               40% |

# %% [markdown]
# ## 3_CIFAR10_LINEAR_S10_LR_1

# %%
# %load CIFAR10_LINEAR_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
#from keras.callbacks import *
import numpy as np
import keras


experiment_name="_LINEAR_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32*32*3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32*32*3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

#tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

linear_model = Sequential()
linear_model.add(Dense(10,
                       activation=sigmoid,
                       input_dim=(32*32*3)))



linear_model.compile(sgd(lr=1),
                     mse, metrics=[categorical_accuracy])


linear_model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=5000,
                 verbose=1,
                 #callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |    47 |      43.70 |   2000 |                  non |               44% |

# %% [markdown]
# ## 4_CIFAR10_LINEAR_T32_S10_LR_1

# %%
# %load CIFAR10_LINEAR_T32_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


experiment_name="_LINEAR_T32_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32*32*3))/255.0
x_test = np.reshape(x_test,(-1,32*32*3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

linear_model = Sequential()
linear_model.add(Dense(32,
                       activation='tanh',
                       input_dim=(32*32*3)))
linear_model.add(Dense(10, activation='sigmoid'))



linear_model.compile(sgd(lr=1),
                     mse, metrics=[categorical_accuracy])


linear_model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |    46 |        42  |   2000 |      vers 920 epochs |                40 |

# %% [markdown]
# ## 5_CIFAR10_LINEAR_1S16_S10_LR_0.5

# %%
# %load CIFAR10_LINEAR_1S16_S10_LR_0.5.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


experiment_name = "CIFAR10_LINEAR_1S16_S10_LR_0.5"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32*32*3))/255.0

x_test = np.reshape(x_test, (-1, 32*32*3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = keras.callbacks.TensorBoard(log_dir='./logs/'+experiment_name, histogram_freq=0, batch_size=32, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)

linear_model = Sequential()
linear_model.add(Dense(16,
                       activation=sigmoid,
                       input_dim=(32*32*3)))
linear_model.add(Dense(10))


linear_model.compile(sgd(lr=0.5,),
                     mse, metrics=[categorical_accuracy])


linear_model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=10000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test, y_test) )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |  42   |    40    | 1000   | vers 789 epochs        |          40%      |

# %% [markdown]
# ## 6_CIFAR10_LINEAR_1S32_S10_LR_0.5

# %%
# %load CIFAR10_LINEAR_1S32_S10_LR_0.5.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


experiment_name = "CIFAR10_LINEAR_1S32_S10_LR_0.5"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32*32*3))/255.0

x_test = np.reshape(x_test, (-1, 32*32*3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("./logs/" + experiment_name)

linear_model = Sequential()
linear_model.add(Dense(32,
                       activation=sigmoid,
                       input_dim=(32*32*3)))
linear_model.add(Dense(10))

linear_model.compile(sgd(lr=0.5),
                     mse, metrics=[categorical_accuracy])


linear_model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=10000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 41 | 40 | 1000 | vers 900 epochs | 40% |

# %% [markdown]
# ## 7_CIFAR10_CONVNET_16_SIGMOID_MAXPOOL_3_DROPOUT_S10_LR_0.5

# %%
# %load CIFAR10_CONVNET_16_SIGMOID_MAXPOOL_3_DROPOUT_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


# /home/user/Documents/ESGI/Machine_Learning/Cifar-10/logs

experiment_name = "CIFAR10_CONVNET_16_SIGMOID_MAXPOOL_3_DROPOUT_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32, 32, 3))/255.0

x_test = np.reshape(x_test, (-1, 32, 32, 3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = keras.callbacks.TensorBoard(log_dir='./logs/'+experiment_name, histogram_freq=0, batch_size=32, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)

conv_model = Sequential()
conv_model.add(Conv2D(16, (3, 3), padding='same', input_shape=(32, 32, 3)))
conv_model.add(Activation('sigmoid'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))
conv_model.add(Flatten())

conv_model.add(Dense(10, activation='sigmoid'))

conv_model.compile(sgd(lr=1, ), mse, metrics=[categorical_accuracy]) 

conv_model.fit(x_train, y_train, batch_size=8000, epochs=2000, verbose=1, callbacks=[tb_callback], validation_data=(x_test, y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 25 | 23 | 30 | non | 23% |

# %% [markdown]
# ## 8_CIFAR10_CONVNET_16_RELU_MAXPOOL_2_DROPOUT_S10_LR_0.5

# %%
# %load CIFAR10_CONVNET_16_RELU_MAXPOOL_2_DROPOUT_S10_LR_0.5.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


experiment_name="_CONVNET_1_32_RELU_1_MAXPOOL_1_2_DROPOUT_0.15_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(16,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.20))


model.add(Flatten())
model.add(Dense(10, activation='sigmoid'))


model.compile(sgd(lr=0.5,),
                     mse, metrics=[categorical_accuracy])


model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 31 | 34 | 2900 | non | 34% |

# %% [markdown]
# ## 9_CIFAR10_CONVNET_16_RELU_MAXPOOL_2_DROPOUT_S10_LR_1

# %%
# %load CIFAR10_CONVNET_16_RELU_MAXPOOL_2_DROPOUT_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


experiment_name="_CONVNET_1_32_RELU_1_MAXPOOL_1_2_DROPOUT_0.15_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(16,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.20))


model.add(Flatten())
model.add(Dense(10, activation='sigmoid'))


model.compile(sgd(lr=1,),
                     mse, metrics=[categorical_accuracy])


model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 57 | 60 |	2000 | non | 60% |

# %% [markdown]
# ## 10_CIFAR10_CONVNET_32_RELU_MAXPOOL_3_DROPOUT_S10_LR_1

# %%
# %load CIFAR10_CONVNET_32_RELU_MAXPOOL_3_DROPOUT_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_CONVNET_32_RELU_MAXPOOL_3_DROPOUT_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(32,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(MaxPool2D((3,3)))
model.add(Flatten())
model.add(Dense(10, activation='sigmoid'))
model.add(Dropout(0.15))

model.compile(sgd(lr=1,),
                     mse, metrics=[categorical_accuracy])


model.fit(x_train, y_train,
                 batch_size=8192,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 68 | 64 | 2000 | vers 1214 epochs	| 62% |

# %% [markdown]
# ## 11_CIFAR10_2CONVNET1_16_16_SIGMOID_MAXPOOL_3_DROPOUT_S10_LR_0.5

# %%
# %load CIFAR10_2CONVNET1_16_16_SIGMOID_MAXPOOL_3_DROPOUT_S10_LR_0.5.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


# /home/user/Documents/ESGI/Machine_Learning/Cifar-10/logs

experiment_name = "CIFAR10_2CONVNET1_16_16_SIGMOID_MAXPOOL_3_DROPOUT_S10_LR_0.5"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32, 32, 3))/255.0

x_test = np.reshape(x_test, (-1, 32, 32, 3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = keras.callbacks.TensorBoard(log_dir='./logs/'+experiment_name, histogram_freq=0, batch_size=32, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)

conv_model = Sequential()
conv_model.add(Conv2D(16, (3, 3), padding='same', input_shape=(32, 32, 3)))
conv_model.add(Activation('sigmoid'))
conv_model.add(Conv2D(16, (3, 3)))
conv_model.add(Activation('sigmoid'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))
conv_model.add(Flatten())

conv_model.add(Dense(10, activation='sigmoid'))

conv_model.compile(sgd(lr=0.5, ), mse, metrics=[categorical_accuracy]) # LR=0.01

conv_model.fit(x_train, y_train, batch_size=8000, epochs=2000, verbose=1, callbacks=[tb_callback], validation_data=(x_test, y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 55 |	57 |	273 |	non |	57% |

# %% [markdown]
# ## 12_CIFAR10_2CONVNET2_16_32_RELU_MAXPOOL_3_DROPOUT_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_16_32_RELU_MAXPOOL_3_DROPOUT_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras

# /home/user/Documents/ESGI/Machine_Learning/Cifar-10/logs

experiment_name = "CIFAR10_2CONVNET2_16_32_RELU_MAXPOOL_3_DROPOUT_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32, 32, 3))/255.0

x_test = np.reshape(x_test, (-1, 32, 32, 3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = keras.callbacks.TensorBoard(log_dir='./logs/'+experiment_name, histogram_freq=0,
                                          batch_size=32, write_graph=True, write_grads=False,
                                          write_images=False, embeddings_freq=0,
                                          embeddings_layer_names=None, embeddings_metadata=None)

conv_model = Sequential()

conv_model.add(Conv2D(16, (3, 3), padding='same', input_shape=(32, 32, 3)))
conv_model.add(Activation('relu'))
conv_model.add(Conv2D(16, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))

conv_model.add(Conv2D(32, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(Conv2D(32, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))

conv_model.add(Flatten())
conv_model.add(Dense(10, activation='sigmoid'))

conv_model.compile(sgd(lr=0.5, ), mse, metrics=[categorical_accuracy])

conv_model.fit(x_train, y_train, batch_size=4000, epochs=20000, verbose=1, callbacks=[tb_callback],
               validation_data=(x_test, y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 11 |	16 |	33 |	non |	16% |

# %% [markdown]
# ## 13_CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_2_DROPOUT_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_2_DROPOUT_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_32_64_RELU_MAXPOOL_2_DROPOUT_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(32,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(32,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))


model.compile(sgd(lr=1,),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 74 |	72 |	2000 |	vers 1527 epochs |	70% |

# %% [markdown]
# ## 14_CIFAR10_2CONVNET2_64_64_RELU_2MAXPOOL2_T64_S10_LR_0.5

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_2MAXPOOL2_T64_S10_LR_0.5.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_2MAXPOOL2_T64_S10_LR_0.5"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("C:\\Users\jujuu\Documents\LogProjet\log" + experiment_name)

model = Sequential()
model.add(Conv2D(8,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))


#on ajoute input
model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))



model.add(Dense(64, activation='tanh'))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))



model.compile(sgd(lr=0.5),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=1000,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)
#ajouter une couche 64

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 45 |	46 |	27 |	non |	47% |

# %% [markdown]
# ## 15_CIFAR10_2CONVNET1_16_16_RELU_MAXPOOL_3_DROPOUT_SM10_LR_1

# %%
# %load CIFAR10_2CONVNET1_16_16_RELU_MAXPOOL_3_DROPOUT_SM10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


# /home/user/Documents/ESGI/Machine_Learning/Cifar-10/logs

experiment_name = "CIFAR10_2CONVNET1_16_16_RELU_MAXPOOL_3_DROPOUT_SM10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32, 32, 3))/255.0

x_test = np.reshape(x_test, (-1, 32, 32, 3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = keras.callbacks.TensorBoard(log_dir='./logs/'+experiment_name, histogram_freq=0, batch_size=32, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)

conv_model = Sequential()
conv_model.add(Conv2D(16, (3, 3), padding='same', input_shape=(32, 32, 3)))
conv_model.add(Activation('relu'))
conv_model.add(Conv2D(16, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))
conv_model.add(Flatten())

conv_model.add(Dense(10, activation='softmax'))

conv_model.compile(sgd(lr=1, ), mse, metrics=[categorical_accuracy]) # LR=0.01

conv_model.fit(x_train, y_train, batch_size=8000, epochs=2000, verbose=1, callbacks=[tb_callback], validation_data=(x_test, y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 27 |	36 |	60 |	non |	36% |

# %% [markdown]
# ## 16_CIFAR10_2CONVNET1_16_16_RELU_MAXPOOL_3_DROPOUT_SP10_LR_1

# %%
# %load CIFAR10_2CONVNET1_16_16_RELU_MAXPOOL_3_DROPOUT_SP10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


# /home/user/Documents/ESGI/Machine_Learning/Cifar-10/logs

experiment_name = "CIFAR10_2CONVNET1_16_16_RELU_MAXPOOL_3_DROPOUT_SP10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32, 32, 3))/255.0

x_test = np.reshape(x_test, (-1, 32, 32, 3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = keras.callbacks.TensorBoard(log_dir='./logs/'+experiment_name, histogram_freq=0, batch_size=32, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)

conv_model = Sequential()
conv_model.add(Conv2D(16, (3, 3), padding='same', input_shape=(32, 32, 3)))
conv_model.add(Activation('relu'))
conv_model.add(Conv2D(16, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))
conv_model.add(Flatten())

conv_model.add(Dense(10, activation='softmax'))

conv_model.compile(sgd(lr=1, ), mse, metrics=[categorical_accuracy]) # LR=0.01

conv_model.fit(x_train, y_train, batch_size=8000, epochs=2000, verbose=1, callbacks=[tb_callback], validation_data=(x_test, y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 19 |	25 |	20 |	non |	25% |

# %% [markdown]
# ## 17_CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_3_DROPOUT_1SP25_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_3_DROPOUT_1SP25_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras

# /home/user/Documents/ESGI/Machine_Learning/Cifar-10/logs

experiment_name = "CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_3_DROPOUT_1SP25_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = np.reshape(x_train, (-1, 32, 32, 3))/255.0

x_test = np.reshape(x_test, (-1, 32, 32, 3))/255.0

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = keras.callbacks.TensorBoard(log_dir='./logs/'+experiment_name, histogram_freq=0,
                                          batch_size=32, write_graph=True, write_grads=False,
                                          write_images=False, embeddings_freq=0,
                                          embeddings_layer_names=None, embeddings_metadata=None)

conv_model = Sequential()

conv_model.add(Conv2D(32, (3, 3), padding='same', input_shape=(32, 32, 3)))
conv_model.add(Activation('relu'))
conv_model.add(Conv2D(110, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))

conv_model.add(Conv2D(64, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(Conv2D(64, (3, 3)))
conv_model.add(Activation('relu'))
conv_model.add(MaxPool2D((3, 3)))
conv_model.add(Dropout(0.20))

conv_model.add(Flatten())
conv_model.add(Dense(25, activation='softplus'))
conv_model.add(Dense(10, activation='sigmoid'))

conv_model.compile(sgd(lr=1, ), mse, metrics=[categorical_accuracy])

conv_model.fit(x_train, y_train, batch_size=4000, epochs=20000, verbose=1, callbacks=[tb_callback],
               validation_data=(x_test, y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 77 |	75 |	800 |	vers 701 epochs |	74% |

# %% [markdown]
# ## 18_CIFAR10_3CONVNET_32_64_32_RELU_3_MAXPOOL_2_DROPOUT_S10_LR_1

# %%
# %load CIFAR10_3CONVNET_32_64_32_RELU_3_MAXPOOL_2_DROPOUT_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import numpy as np
import keras


experiment_name="CIFAR10_3CONVNET_32_64_32_RELU_3_MAXPOOL_2_DROPOUT_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("C:\\Users\jujuu\Documents\LogProjet\log" + experiment_name)

model = Sequential()
model.add(Conv2D(32,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.10))

model.add(Conv2D(32,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.20))


model.add(Flatten())
model.add(Dense(10, activation='sigmoid'))


model.compile(sgd(lr=1,),
                     mse, metrics=[categorical_accuracy])


model.fit(x_train, y_train,
                 batch_size= 2000,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test), )

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |    72 |         72 |   662  |                non   |         72%       |

# %% [markdown]
# ## 19_CIFAR10_3CONVNET2_64_64_64_RELU_MAXPOOL_DROPOUT_S10_LR_0.05

# %%
# %load CIFAR10_3CONVNET2_64_64_64_RELU_MAXPOOL_DROPOUT_S10_LR_0.05.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_3CONVNET2_64_64_64_RELU_MAXPOOL_DROPOUT_S10_LR_0.05"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(sgd(lr=0.05),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 64 |	65 |	10000 |	non |	65% |

# %% [markdown]
# ## 20_CIFAR10_3CONVNET2_64_64_64_RELU_MAXPOOL_DROPOUT_S10_LR_1

# %%
# %load CIFAR10_3CONVNET2_64_64_64_RELU_MAXPOOL_DROPOUT_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_3CONVNET2_64_64_64_RELU_MAXPOOL_DROPOUT_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(sgd(lr=0.05),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 76 |	75 |	3577 |	non |	75% |

# %% [markdown]
# ## 21_CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_DROPOUT_T64_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_DROPOUT_T64_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_32_64_RELU_MAXPOOL_DROPOUT_T64_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(32,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(32,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='tanh'))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(sgd(lr=0.05),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 89 |	76 |	2000 |	vers 625 epochs |	71% |

# %% [markdown]
# ## 22_CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_DROPOUT_R64_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_32_64_RELU_MAXPOOL_DROPOUT_R64_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_32_64_RELU_MAXPOOL_DROPOUT_R64_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(32,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(32,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='relu'))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(sgd(lr=0.05),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
#  | 81	| 74	| 860	| vers 530 epochs |	71% |

# %% [markdown]
# ## 23_
# ## CIRFAR10_2CONVNET2_64_64_RELU_2MAXPOOL2_2_DROPOUT_2_2T64_S10_LR_1

# %%
# %load CIRFAR10_2CONVNET2_64_64_RELU_2MAXPOOL2_2_DROPOUT_2_2T64_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="CIRFAR10_2CONVNET2_64_64_RELU_2MAXPOOL2_2_DROPOUT_2_2T64_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("C:\\Users\jujuu\Documents\LogProjet\log" + experiment_name)

model = Sequential()
model.add(Conv2D(8,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

#on ajoute input
model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='tanh'))
model.add(Dense(64, activation='tanh'))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

#keras.optimizers.RMSprop(lr=0.001)


model.compile(sgd(lr=1,),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=500,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)
#ajouter une couche 64

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 93 |	78 |	488 |	vers 80 epochs |	74% |

# %% [markdown]
# ## 24_CIFAR10_1CONVNET2_64_RELU_MAXPOOL_DROPOUT_T64_S10_LR_1

# %%
# %load CIFAR10_1CONVNET2_64_RELU_MAXPOOL_DROPOUT_T64_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

experiment_name = "CIFAR10_1CONVNET2_64_RELU_MAXPOOL_DROPOUT_T64_S10_LR_1"

x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("C:\\Users\jujuu\Documents\LogProjet\log" + experiment_name)

model = Sequential()
model.add(Conv2D(8,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

#on ajoute input


model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='tanh'))
model.add(Dense(64, activation='tanh'))

model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))


model.compile(sgd(lr=1,),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=1000,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 64 |	63 |	73 |	non	| 63% |

# %% [markdown]
# ## 25_CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_2R64_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3R64_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3R64_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(sgd(lr=1,),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 95 |	78 |	2000	| vers 708 epochs	| 76.5% |

# %% [markdown]
# ## 26_CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3R64_SM10_LR_1

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3R64_SM10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3R64_SM10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Flatten())
model.add(Dense(10,activation='softmax'))

model.compile(sgd(lr=1,),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 95 | 	76	|1200	|vers 418 epochs|	74%|

# %% [markdown]
# ## 27_CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3T64_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3T64_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3T64_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(sgd(lr=1),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |94	 | 79.01	|2000	|vers 608 epochs	|78% |

# %% [markdown]
# ## 28_CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_S10_LR_1

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_S10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_S10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='elu'))
model.add(Dense(64, activation='elu'))
model.add(Dense(64, activation='elu'))
model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))


model.compile(sgd(lr=1,),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |95	|79.46|	2000|	vers 450 epochs	|76.85%|

# %% [markdown]
# ## 29_CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_SM10_LR_1

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_SM10_LR_1.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_SM10_LR_1"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='elu'))
model.add(Dense(64, activation='elu'))
model.add(Dense(64, activation='elu'))
model.add(Flatten())
model.add(Dense(10,activation='softmax'))

model.compile(sgd(lr=1,),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# | 97|	78 |	2000 |	vers 364 epochs	|76.33% |

# %% [markdown]
# ## 30_
# ## CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_S10_LR_1_RMSPROP

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_S10_LR_1_RMSPROP.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT_3E64_S10_LR_1_RMSPROP"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.20))

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.10))

model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(keras.optimizers.RMSprop(lr=0.001),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |96.80|	78	|2000	|vers 118 epochs|	76.12% |

# %% [markdown]
# ## 31_CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT50_3E64_S10_LR_1_RMSPROP

# %%
# %load CIFAR10_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT50_3E64_S10_LR_1_RMSPROP.py
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.losses import *
from keras.datasets import *
from keras.metrics import *
from keras.callbacks import *
import theano
import numpy as np
import keras


experiment_name="_2CONVNET2_64_64_RELU_MAXPOOL_2_DROPOUT50_3E64_S10_LR_1_RMSPROP"

(x_train, y_train), (x_test, y_test) = cifar10.load_data()



x_train = np.reshape(x_train,(-1,32,32,3))/255.0 #1024 cifar
x_test = np.reshape(x_test,(-1,32,32,3))/255.0


y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

print(x_train.shape)
print(y_train.shape)

tb_callback = TensorBoard("E:\\Documents\logs_deep_learning\CIFAR10" + experiment_name)

model = Sequential()
model.add(Conv2D(64,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.30)) #0.20

model.add(Conv2D(64,(3,3),padding='same',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))

model.add(MaxPool2D(2,2))
model.add(Dropout(0.50))  #0.10

model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Flatten())
model.add(Dense(10,activation='sigmoid'))

model.compile(keras.optimizers.RMSprop(lr=0.001),
              mse, metrics=[categorical_accuracy])

model.fit(x_train, y_train,
                 batch_size=2048,
                 epochs=2000,
                 verbose=1,
                 callbacks=[tb_callback],
                 validation_data=(x_test,y_test),)

# %% [markdown]
# | Categ | Val Categ  | Epochs | Surapprentissage Obs | Pourcentage gardé |
# |-------|------------|--------|----------------------|-------------------|
# |94	|78	|2000	|vers 519 epochs	|80.07%|
